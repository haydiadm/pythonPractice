# %% [markdown]
# <a href="https://colab.research.google.com/github/haydiadm/pythonPractice/blob/main/shoppingList_VF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome to my grocery list app. It has the following operations that it supports:')
operations = {
"1": "Show shopping list."
"2": "Add Item to the list."
"3": "Remove Item from list."
"4": "Exit"
}
def shopping():
  shopping_list =[]
 if oper == "1":
  if len(shopping_list)= 0
    result = print("No items in your list for now")
  else
    result = print(' Your grocery list is:'\n + shopping_list)
 elif oper == "2":
  print("Enter list item description:")
  add_item = input("Enter list item description:")
  shopping_list.append(add_item)
  result = print(' Your grocery list has been updated and it now looks like this:'\n + shopping_list)

 elif oper == "3":
  print("Your grocery list currently looks like this:"\n + shopping_list)
  if len(shopping_list = 0)
    print("there is nothing to remove")
  else
    remove_item = input("Enter the number of the item you want to remove:")
    result = shopping_list.pop(remove_item)
 elif oper == "4":
  
  
  
    
    result = 'You have chosen to exit. We hope you use our app again. Bye :).'
 else :
  result = 'invalid operator'
 return result  


def get_operands():
  operation_name = operations[oper]
  print('You have chosen ' + operation_name 'The results are shown below.')

# %%
print('Welcome to my grocery list app. It has the following operations that it supports:')
print('1. Show shopping list.')
print('2. Add Item to the list.')
print('3. Remove Item from list.')
print('4. Exit')
oper = input('Please enter a number for the kind of operation you want to perform:\n') 
shopping_list =[]
def printList(shopping_list):
  i= 0
  for x in shopping_list:
    i= i+1
    print(str(i) + '.' + x)


def shopping():
  if oper == "1":
    if len(shopping_list) == 0:
      print("No items in your list for now")
    else:
      print(' Your grocery list is:\n')
      printList(shopping_list)
  elif oper == "2":
    print("Enter list item description:")
    add_item = input("Enter list item description:")
    shopping_list.append(add_item)
    print('Your grocery list has been updated and it now looks like this:\n')
    printList(shopping_list)

  elif oper == "3":
    if len(shopping_list) == 0:
      print("there is nothing to remove")
    else:
      print("Your grocery list currently looks like this:\n")
      printList(shopping_list)
      remove_item = input("Enter the number of the item you want to remove:")
      remove_item = int(remove_item) - 1
      if remove_item  < len(shopping_list) and remove_item >= 0 : 
        shopping_list.pop(remove_item)
        print('Now your List only contains this:')
        printList(shopping_list)
      else:
        print('Invalid index')  
  elif oper == "4":
      print('You have chosen to exit. We hope you use our app again. Bye :).')
  else :
    print('invalid operator')


while oper != "4":
  
  shopping()
  print('Welcome to my grocery list app. It has the following operations that it supports:')
  print('1. Show shopping list.')
  print('2. Add Item to the list.')
  print('3. Remove Item from list.')
  print('4. Exit')
  oper = input('Please enter a number for the kind of operation you want to perform:\n')
# Out:
# Welcome to my grocery list app. It has the following operations that it supports:
# 1. Show shopping list.
# 2. Add Item to the list.
# 3. Remove Item from list.
# 4. Exit
# Please enter a number for the kind of operation you want to perform:
# 2
# Enter list item description:
# Enter list item description:milk
# Your grocery list has been updated and it now looks like this:
#
# 1.milk
# Welcome to my grocery list app. It has the following operations that it supports:
# 1. Show shopping list.
# 2. Add Item to the list.
# 3. Remove Item from list.
# 4. Exit
# Please enter a number for the kind of operation you want to perform:
# 2
# Enter list item description:
# Enter list item description:eggs
# Your grocery list has been updated and it now looks like this:
#
# 1.milk
# 2.eggs
# Welcome to my grocery list app. It has the following operations that it supports:
# 1. Show shopping list.
# 2. Add Item to the list.
# 3. Remove Item from list.
# 4. Exit
# ...
